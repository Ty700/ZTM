# %%
import pandas as pd
data_frame = pd.read_csv('./salaries.csv')
data_frame.shape # 16494 Rows, 11 cols
# Out:
# (16494, 11)

# %%
data_frame.head()
# Out:
#    work_year experience_level employment_type             job_title  salary  \
# 0       2024               MI              FT        Data Scientist  120000
# 1       2024               MI              FT        Data Scientist   70000
# 2       2024               MI              CT        Data Scientist  130000
# 3       2024               MI              CT        Data Scientist  110000
# 4       2024               MI              FT  Data Science Manager  240000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         120000                 AU             0
# 1             USD          70000                 AU             0
# 2             USD         130000                 US             0
# 3             USD         110000                 US             0
# 4             USD         240000                 US             0
#
#   company_location company_size
# 0               AU            S
# 1               AU            S
# ...

# %%
data_frame[data_frame['employee_residence'] == 'US'] # This filters to only include people residing in US
# Out:
#        work_year experience_level employment_type  \
# 2           2024               MI              CT
# 3           2024               MI              CT
# 4           2024               MI              FT
# 5           2024               MI              FT
# 6           2024               SE              FT
# ...          ...              ...             ...
# 16488       2021               SE              FT
# 16489       2020               SE              FT
# 16490       2021               MI              FT
# 16491       2020               EN              FT
# 16492       2020               EN              CT
#
#                             job_title  salary salary_currency  salary_in_usd  \
# 2                      Data Scientist  130000             USD         130000
# 3                      Data Scientist  110000             USD         110000
# 4                Data Science Manager  240000             USD         240000
# ...
